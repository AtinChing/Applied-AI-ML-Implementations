# %% [markdown]
# # What is NLP?
# NLP (Natural Language Processing) is the broader field focused on enabling computers to understand, interpret, and generate human language. NLP encompasses many techniques and tasks such as sentiment analysis, named entity recognition, and machine translation.
# The focus is on understanding everything related to human language. The aim of NLP tasks is not only to understand single words individually, but to be able to understand the context of those words.
#
# The following is a list of common NLP tasks, with some examples of each:
#
# - Classifying whole sentences: Getting the sentiment of a review, detecting if an email is spam, determining if a sentence is grammatically correct or whether two sentences are logically related or not
# - Classifying each word in a sentence: Identifying the grammatical components of a sentence (noun, verb, adjective), or the named entities (person, location, organization)
# - Generating text content: Completing a prompt with auto-generated text, filling in the blanks in a text with masked words
# - Extracting an answer from a text: Given a question and a context, extracting the answer to the question based on the information provided in the context
# - Generating a new sentence from an input text: Translating a text into another language, summarizing a text
#
# NLP isn’t limited to written text though. It also tackles complex challenges in speech recognition and computer vision, such as generating a transcript of an audio sample or a description of an image.

# %% [markdown]
# ## Sequence Data
# In many of the notebooks in the rest of this repository, we've mostly looked at data that we could represent as one static data point where the notion of time or step was irrelevant. Take for example our reddit data, it was simply a bunch of dict objects. That data doesn't change or care about the notion of time.
#
# In the `nlp/` section of this repo that we're in right now, we will mostly be looking at sequences of text and learn how we can encode them in a meaningful way. Unlike the types of data we have looked at, sequence data such as long chains of text, weather patterns, videos and really anything where the notion of a step or time is relevant needs to be processed and handled in a special way.
#
# #### Why is text data considered a sequence?
# Since textual data contains many words that follow in a very specific and meaningful order, we need to be able to keep track of each word and when it occurs in the data. Simply encoding say an entire paragraph of text into one data point wouldn't give us a very meaningful picture of the data and would be very difficult to do anything with. This is why we treat text as a sequence and process one word at a time. We will keep track of where each of these words appear and use that information to try to understand the meaning of pieces of text.
#
# ## Evolution of NLP Models
# - To handle the aforementioned NLP tasks, and NLP in general, different types of models (neural networks specifically) have been introduced that are meant to be specialized and highly capable in being able to process this kind of data and solve these sort of tasks they're meant to be used for.
# - These models have evolved over time to become more and more fit for NLP purposes. I have provided an extremely brief overview of them below, and have expanded upon each one in greater detail in their own respective sole notebooks. Those notebooks have been linked for each corresponding section/type.
#
# ### Recurrent Neural Networks (RNNs)
# - Process input tokens **sequentially**
# - Struggle with long-term memory
# - Hard to parallelize
#
# To understand how RNNs work under the hood, check out [RNNs ➤](recurrent_neural_networks.ipynb)
#
# ### Long Short-Term Memory (LSTM)
# - Upgrade of RNNs with better long-term memory
# - Still sequential and slow to train
# - Better than RNNs, but still not scalable
#
# To understand how LSTMs work under the hood, check out [LSTMs ➤](lstm.ipynb)
#
# ### Transformers
# - Use **attention** to look at all words at once
# - No recurrence — parallelizable and scalable
# - Models like BERT, GPT, and T5 use this architecture
#
# To understand how transformers work under the hood, check out [Transformer Architecture ➤](../foundations/transformers.ipynb)
#
#
# Once you've gone through the above notebooks, you will have a conceptual grounding in NLP. You can then dive into:
# - The role of tokenization and embeddings
# - Why vector representations matter
# - How transformers consume and process sequences (if you haven't gone over the transformers notebook).
#
# The notebooks for those are:
# - [Tokenization ➤](tokenization.ipynb)
# - [Vector Embeddings ➤](../vector_search/vector_embeddings.ipynb)
# - [Transformer Architecture ➤](../foundations/transformers.ipynb)
#
# Once you move through the aforementioned notebooks, you will have learned all the necessary parts for bridging your overall understanding of NLP all together.
#
# ## Tasks and applications
#
# Now, you can move through the applications'/tasks' notebooks to strengthen your understanding and practice!
#
# Each notebook below dives deeper into specific tasks of NLP. You can find them linked here:
#
# - [Text Classification (BERT) ➤](../llms/text_classification_bert.ipynb)
# - [Text Generation (GPT-2) ➤](../llms/text_generation_gpt2.ipynb)
